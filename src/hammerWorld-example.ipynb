# %%
# %load_ext autoreload
# %autoreload 2
from pddl import parser
from pddl.pddl_world import *
from find_macpo import find_macpo
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
domain = parser.parse_domain_file('../pddl/hammerworld-domain.pddl')
problem = parser.parse_problem_file('../pddl/hammerworld-problem-threat.pddl')

# %%
# Out:
# PDDL Problem:
# Objects:
#      hammer
#      hammer
#      nail
#      nail
#      sandwich
#      pizza
# Initial Conditions: World State:
#      (stored hammer)
#      (stored nail)
# Goal Conditions:
#      (hammered nail)
#      (stored hammer)

# %%
find_object = domain.operator_schemas['find-object']
pickup_object = domain.operator_schemas['pickup-object']
hammer_nail = domain.operator_schemas['hammer-nail']
store_object = domain.operator_schemas['store-object']
eat_something = domain.operator_schemas['eat-something']
hammer = problem.get_object('hammer').name
nail = problem.get_object('nail').name
sandwich = problem.get_object('sandwich').name

find_object
# Out:
# Operator Schema: find-object
#    Parameters: ?o-object
#    Preconds:   (stored ?o)
#    Add Eff:    (located ?o)
#    Del Eff:    (stored ?o)

# %%
problem.objects[3].objType
# Out:
# 'nail'

# %%
iniState = State(problem.initial_conditions.predicates)
endState = State(problem.goal_conditions)

# %%
from IPython.core.display import SVG, Image
from IPython.display import display, display_svg, display_png
from plan_graphs import PartialOrderGraph, TotalOrderGraph

# %%
# Creating an action sequence
asec = ActionSequence(iniState, endState)
state_sequence = [iniState]
state_sequence.append(asec.add_action_step(ActionStep(find_object, [hammer]), state_sequence[-1]))
state_sequence.append(asec.add_action_step(ActionStep(pickup_object, [hammer]), state_sequence[-1]))
state_sequence.append(asec.add_action_step(ActionStep(find_object, [nail]), state_sequence[-1]))
state_sequence.append(asec.add_action_step(ActionStep(pickup_object, [nail]), state_sequence[-1]))
state_sequence.append(asec.add_action_step(ActionStep(eat_something, [sandwich]), state_sequence[-1]))
state_sequence.append(asec.add_action_step(ActionStep(hammer_nail, [hammer, nail]), state_sequence[-1]))
state_sequence.append(asec.add_action_step(ActionStep(store_object, [hammer]), state_sequence[-1]))
total_order_graph = TotalOrderGraph(asec)
print(asec)
display(total_order_graph)
dot_code = total_order_graph.dot_graph.to_string()
# Out:
# Action Sequence:
#    Initial Conditions: (stored hammer) (stored nail)
#    Step 0: (find-object hammer)
#    Step 1: (pickup-object hammer)
#    Step 2: (find-object nail)
#    Step 3: (pickup-object nail)
#    Step 4: (eat-something sandwich)
#    Step 5: (hammer-nail hammer nail)
#    Step 6: (store-object hammer)
#    Goal Conditions: (hammered nail) (stored hammer)
# <plan_graphs.TotalOrderGraph instance at 0x10d855830>

# %%
state_sequence
# Out:
# [State:
#    Predicates:   (stored hammer) (stored nail)
# ,
#  State:
#    Predicates:   (stored nail) (located hammer)
# ,
#  State:
#    Predicates:   (stored nail) (has hammer)
# ,
#  State:
#    Predicates:   (has hammer) (located nail)
# ,
#  State:
#    Predicates:   (has hammer) (has nail)
# ,
#  State:
#    Predicates:   (has hammer) (has nail) (clean labbench)
# ,
#  State:
#    Predicates:   (has hammer) (clean labbench) (hammered nail)
# ,
#  State:
#    Predicates:   (clean labbench) (hammered nail) (stored hammer)
# ]

# %%
# Find Partial Order Graph (no threat resolution)
po_plan_nothreats = find_macpo(asec, state_sequence, False)
print(po_plan_nothreats)
po_graph_nothreats = PartialOrderGraph(po_plan_nothreats)
display(po_graph_nothreats)
# Out:
# Partial Order Plan:
# Initial State:
#    Predicates:   (stored hammer) (stored nail)
# Goal State:
#    Predicates:   (hammered nail) (stored hammer)
#
# Causal Links:
#    Causal Link 0: (hammer-nail hammer nail ---((hammered nail))---> GOAL)
#    Causal Link 1: (store-object hammer ---((stored hammer))---> GOAL)
#    Causal Link 2: (pickup-object hammer ---((has hammer))---> store-object hammer)
#    Causal Link 3: (pickup-object hammer ---((has hammer))---> hammer-nail hammer nail)
#    Causal Link 4: (pickup-object nail ---((has nail))---> hammer-nail hammer nail)
#    Causal Link 5: (find-object nail ---((located nail))---> pickup-object nail)
#    Causal Link 6: (START ---((stored nail))---> find-object nail)
#    Causal Link 7: (find-object hammer ---((located hammer))---> pickup-object hammer)
#    Causal Link 8: (START ---((stored hammer))---> find-object hammer)
#    Causal Link 9: (START ---()---> eat-something sandwich)
# <plan_graphs.PartialOrderGraph instance at 0x10c7db248>

# %%
# Find Partial Order Graph (threat resolution)
po_plan_threats = find_macpo(asec, state_sequence, True)
print(po_plan_threats)
po_graph_threats = PartialOrderGraph(po_plan_threats)
display(po_graph_threats)
# Out:
# Partial Order Plan:
# Initial State:
#    Predicates:   (stored hammer) (stored nail)
# Goal State:
#    Predicates:   (hammered nail) (stored hammer)
#
# Causal Links:
#    Causal Link 0: (hammer-nail hammer nail ---((hammered nail))---> GOAL)
#    Causal Link 1: (store-object hammer ---((stored hammer))---> GOAL)
#    Causal Link 2: (pickup-object hammer ---((has hammer))---> store-object hammer)
#    Causal Link 3: (pickup-object hammer ---((has hammer))---> hammer-nail hammer nail)
#    Causal Link 4: (pickup-object nail ---((has nail))---> hammer-nail hammer nail)
#    Causal Link 5: (find-object nail ---((located nail))---> pickup-object nail)
#    Causal Link 6: (START ---((stored nail))---> find-object nail)
#    Causal Link 7: (find-object hammer ---((located hammer))---> pickup-object hammer)
#    Causal Link 8: (START ---((stored hammer))---> find-object hammer)
#    Causal Link 9: (START ---()---> eat-something sandwich)
#    Causal Link 10: (find-object hammer ---((stored hammer))---> store-object hammer)
#    Causal Link 11: (hammer-nail hammer nail ---((has hammer))---> store-object hammer)
# <plan_graphs.PartialOrderGraph instance at 0x10c797518>

# %%
total_order_graph.dot_graph.write_svg('to_graph.svg')
po_graph_threats.dot_graph.write_svg('po_graph.svg')
# Out:
# True
